# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import requests
from pathlib import Path
sns.set_style("whitegrid")

# %%
demographics=pd.read_csv('./demographics/demographics_cleaned.csv')
demographics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3220 entries, 0 to 3219
# Data columns (total 43 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        3220 non-null   int64
#  1   GEO_ID            3220 non-null   object
#  2   NAME              3220 non-null   object
#  3   total_pop         3220 non-null   int64
#  4   pop_0_5           3220 non-null   int64
#  5   pop_5_10          3220 non-null   int64
#  6   pop_10_15         3220 non-null   int64
#  7   pop_15_20         3220 non-null   int64
#  8   pop_20_25         3220 non-null   int64
#  9   pop_25_30         3220 non-null   int64
#  10  pop_30_35         3220 non-null   int64
#  11  pop_35_40         3220 non-null   int64
#  12  pop_40_45         3220 non-null   int64
#  13  pop_45_50         3220 non-null   int64
#  14  pop_50_55         3220 non-null   int64
#  15  pop_55_60         3220 non-null   int64
#  16  pop_60_65         3220 non-null   int64
#  17  pop_65_70         3220 non-null   int64
#  18  pop_70_75         3220 non-null   int64
#  19  pop_75_80         3220 non-null   int64
#  20  pop_80_85         3220 non-null   int64
#  21  pop_85_90         3220 non-null   int64
#  22  pop_18_24         3220 non-null   int64
#  23  total_male_pop    3220 non-null   int64
#  24  pop_male_0_5      3220 non-null   int64
#  25  pop_male_5_10     3220 non-null   int64
#  26  pop_male_10_15    3220 non-null   int64
#  27  pop_male_15_20    3220 non-null   int64
#  28  pop_male_20_25    3220 non-null   int64
#  29  pop_male_25_30    3220 non-null   int64
#  30  pop_male_30_35    3220 non-null   int64
#  31  pop_male_35_40    3220 non-null   int64
#  32  pop_male_40_45    3220 non-null   int64
#  33  pop_male_45_50    3220 non-null   int64
#  34  pop_male_50_55    3220 non-null   int64
#  35  pop_male_55_60    3220 non-null   int64
#  36  pop_male_60_65    3220 non-null   int64
#  37  pop_male_65_70    3220 non-null   int64
#  38  pop_male_70_75    3220 non-null   int64
#  39  pop_male_75_80    3220 non-null   int64
#  40  pop_male_80_85    3220 non-null   int64
#  41  pop_male_85_90    3220 non-null   int64
#  42  pop_male_105_110  3220 non-null   int64
# dtypes: int64(41), object(2)
# memory usage: 1.1+ MB

# %%
#better_demographics=demographics[['GEO_ID','NAME']]

# %%
demographics['pop_18_30']=demographics['pop_18_24']+demographics['pop_25_30']
demographics['pop_18_30_pc']=100*demographics['pop_18_30']/demographics['total_pop']
demographics['pop_60_up']=demographics['pop_60_65']+demographics['pop_65_70']+demographics['pop_70_75']+demographics['pop_75_80']+demographics['pop_80_85']+demographics['pop_85_90']
demographics['pop_60_up_pc']=100*demographics['pop_60_up']/demographics['total_pop']

demographics['pop_male_pc']=100*demographics['total_male_pop']/demographics['total_pop']
final_tally=demographics[['GEO_ID','NAME','total_pop','pop_18_30_pc','pop_60_up_pc','pop_male_pc']]

# %%
final_tally.set_index('GEO_ID',inplace=True)

# %%
final_tally.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3220 entries, 0500000US01001 to 0500000US72153
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   NAME          3220 non-null   object
#  1   total_pop     3220 non-null   int64
#  2   pop_18_30_pc  3220 non-null   float64
#  3   pop_60_up_pc  3220 non-null   float64
#  4   pop_male_pc   3220 non-null   float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 150.9+ KB

# %%
dp_2016=pd.read_csv('./demographics/dp_2016_cleaned.csv')
dp_2019=pd.read_csv('./demographics/dp_2019_cleaned.csv')
dp_2016.drop(axis=1,labels=['Unnamed: 0'],inplace=True)
dp_2019.drop(axis=1,labels=['Unnamed: 0'],inplace=True)
dp_2016.set_index('GEO_ID',inplace=True)
dp_2019.set_index('GEO_ID',inplace=True)

# %%
dp_2019.loc[:,'tot_pop']
# Out:
# GEO_ID
# 0500000US01001     55380
# 0500000US01003    212830
# 0500000US01005     25361
# 0500000US01007     22493
# 0500000US01009     57681
#                    ...
# 0500000US72145     52192
# 0500000US72147      8642
# 0500000US72149     22403
# 0500000US72151     33499
# 0500000US72153     35428
# Name: tot_pop, Length: 3220, dtype: int64

# %%
delta_dp=dp_2016[['NAME']]
for x in dp_2016.columns:
    if x != 'NAME':
        dp_2016[x+'_pc']=100*dp_2016[x]/dp_2016['tot_pop']
        dp_2019[x+'_pc']=100*dp_2019[x]/dp_2019['tot_pop']
        delta_dp.loc[:,x+'_delta']=dp_2019[(x+'_pc')]-dp_2016[(x+'_pc')]
delta_dp.drop(axis=1,labels=['tot_pop_delta'],inplace=True)
# Out:
# /tmp/ipykernel_427111/176667491.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delta_dp.loc[:,x+'_delta']=dp_2019[(x+'_pc')]-dp_2016[(x+'_pc')]
# /tmp/ipykernel_427111/176667491.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delta_dp.loc[:,x+'_delta']=dp_2019[(x+'_pc')]-dp_2016[(x+'_pc')]
# /tmp/ipykernel_427111/176667491.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delta_dp.loc[:,x+'_delta']=dp_2019[(x+'_pc')]-dp_2016[(x+'_pc')]
# /tmp/ipykernel_427111/176667491.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delta_dp.loc[:,x+'_delta']=dp_2019[(x+'_pc')]-dp_2016[(x+'_pc')]
# /tmp/ipykernel_427111/176667491.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delta_dp.loc[:,x+'_delta']=dp_2019[(x+'_pc')]-dp_2016[(x+'_pc')]
# /tmp/ipykernel_427111/176667491.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delta_dp.loc[:,x+'_delta']=dp_2019[(x+'_pc')]-dp_2016[(x+'_pc')]
# /tmp/ipykernel_427111/176667491.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delta_dp.drop(axis=1,labels=['tot_pop_delta'],inplace=True)

# %%
cols=['afr_amer','amer_ind','asian','latino','white']
final_tally.loc[:,[x+'_pc' for x in cols]]=dp_2019.loc[:,[ x+'_pc' for x in cols]]
final_tally.loc[:,[x+'_delta' for x in cols]]=delta_dp.loc[:,[x+'_delta' for x in cols]]

# %%
final_tally.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3220 entries, 0500000US01001 to 0500000US72153
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   NAME            3220 non-null   object
#  1   total_pop       3220 non-null   int64
#  2   pop_18_30_pc    3220 non-null   float64
#  3   pop_60_up_pc    3220 non-null   float64
#  4   pop_male_pc     3220 non-null   float64
#  5   afr_amer_pc     3220 non-null   float64
#  6   amer_ind_pc     3220 non-null   float64
#  7   asian_pc        3220 non-null   float64
#  8   latino_pc       3220 non-null   float64
#  9   white_pc        3220 non-null   float64
#  10  afr_amer_delta  3220 non-null   float64
#  11  amer_ind_delta  3220 non-null   float64
#  12  asian_delta     3220 non-null   float64
#  13  latino_delta    3220 non-null   float64
#  14  white_delta     3220 non-null   float64
# dtypes: float64(13), int64(1), object(1)
# memory usage: 402.5+ KB

# %%
poverty_2019=pd.read_csv('./poverty/poverty_2019_cleaned.csv',engine='python')
poverty_2016=pd.read_csv('./poverty/poverty_2016_cleaned.csv',engine='python')
poverty_2016.set_index('GEO_ID',inplace=True)
poverty_2019.set_index('GEO_ID',inplace=True)
poverty_2016.drop(axis=1,labels=['Unnamed: 0'],inplace=True)
poverty_2019.drop(axis=1,labels=['Unnamed: 0'],inplace=True)

# %%
poverty_2016['pov_pc']=100*poverty_2016['tot_poverty']/final_tally['total_pop']
poverty_2019['pov_pc']=100*poverty_2019['tot_poverty']/final_tally['total_pop']
poverty_2016['pov_150_pc']=100*poverty_2016['pov_150']/final_tally['total_pop']
poverty_2019['pov_150_pc']=100*poverty_2019['pov_150']/final_tally['total_pop']

# %%
final_tally['pov_pc']=poverty_2019['pov_pc']
final_tally['pov_pc_delta']=poverty_2019['pov_pc']-poverty_2016['pov_pc']
# Out:
# /tmp/ipykernel_427111/69067233.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_tally['pov_pc']=poverty_2019['pov_pc']
# /tmp/ipykernel_427111/69067233.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_tally['pov_pc_delta']=poverty_2019['pov_pc']-poverty_2016['pov_pc']

# %%
final_tally[:5]
# Out:
#                                    NAME  total_pop  pop_18_30_pc  \
# GEO_ID
# 0500000US01001  Autauga County, Alabama      55380     15.185988
# 0500000US01003  Baldwin County, Alabama     212830     12.994879
# 0500000US01005  Barbour County, Alabama      25361     15.444975
# 0500000US01007     Bibb County, Alabama      22493     14.591206
# 0500000US01009   Blount County, Alabama      57681     13.876320
#
#                 pop_60_up_pc  pop_male_pc  afr_amer_pc  amer_ind_pc  asian_pc  \
# GEO_ID
# 0500000US01001     19.902492    48.634886    19.028530     0.252799  1.034670
# 0500000US01003     27.178029    48.628483     9.264671     0.772917  0.925152
# 0500000US01005     25.022673    52.919838    47.576988     0.323331  0.528370
# 0500000US01007     22.442538    54.016805    22.291380     0.133375  0.120037
# 0500000US01009     24.505470    49.401016     1.608849     0.079749  0.367539
#
#                 latino_pc   white_pc  afr_amer_delta  amer_ind_delta  \
# GEO_ID
# 0500000US01001   2.825930  76.791260        0.506849       -0.157744
# 0500000US01003   4.562797  86.205422       -0.055162        0.093753
# 0500000US01005   4.357084  46.800205       -0.352673        0.150490
# 0500000US01007   2.574134  76.788334        1.079258       -0.225477
# 0500000US01009   9.261282  95.459510        0.040500       -0.268580
#
#                 asian_delta  latino_delta  white_delta     pov_pc  \
# GEO_ID
# 0500000US01001     0.228115      0.253676    -0.069355  15.059588
# 0500000US01003     0.254508      0.196098    -0.226837  10.197810
# 0500000US01005     0.043663      0.047322     0.095463  27.108553
# 0500000US01007     0.058014      0.350140    -0.165414  16.627395
# 0500000US01009     0.208104      0.533984     0.018986  13.416896
#
#                 pov_pc_delta
# GEO_ID
# 0500000US01001      2.966775
# 0500000US01003     -1.807546
# 0500000US01005      2.523560
# 0500000US01007      1.556040
# 0500000US01009     -2.950712

# %%
income_2019=pd.read_csv('./income/income_2019_cleaned.csv',engine='python')
income_2016=pd.read_csv('./income/income_2016_cleaned.csv',engine='python')
income_2016.set_index('GEO_ID',inplace=True)
income_2019.set_index('GEO_ID',inplace=True)
income_2016.drop(axis=1,labels=['Unnamed: 0'],inplace=True)
income_2019.drop(axis=1,labels=['Unnamed: 0'],inplace=True)

# %%
final_tally['unemp_rate']=income_2019['unemp_rate']
final_tally['unemp_delta']=income_2019['unemp_rate']-income_2016['unemp_rate']
final_tally['mean_hhi']=income_2019['mean_hh_inc']
final_tally['med_hhi']=income_2019['med_hh_inc']
# Out:
# /tmp/ipykernel_427111/3753765977.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_tally['unemp_rate']=income_2019['unemp_rate']
# /tmp/ipykernel_427111/3753765977.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_tally['unemp_delta']=income_2019['unemp_rate']-income_2016['unemp_rate']
# /tmp/ipykernel_427111/3753765977.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_tally['mean_hhi']=income_2019['mean_hh_inc']
# /tmp/ipykernel_427111/3753765977.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_tally['med_hhi']=income_2019['med_hh_inc']

# %%
final_tally
# Out:
#                                             NAME  total_pop  pop_18_30_pc  \
# GEO_ID
# 0500000US01001           Autauga County, Alabama      55380     15.185988
# 0500000US01003           Baldwin County, Alabama     212830     12.994879
# 0500000US01005           Barbour County, Alabama      25361     15.444975
# 0500000US01007              Bibb County, Alabama      22493     14.591206
# 0500000US01009            Blount County, Alabama      57681     13.876320
# ...                                          ...        ...           ...
# 0500000US72145  Vega Baja Municipio, Puerto Rico      52192     16.117413
# 0500000US72147    Vieques Municipio, Puerto Rico       8642     13.607961
# 0500000US72149   Villalba Municipio, Puerto Rico      22403     17.457483
# 0500000US72151    Yabucoa Municipio, Puerto Rico      33499     15.803457
# 0500000US72153      Yauco Municipio, Puerto Rico      35428     14.663543
#
#                 pop_60_up_pc  pop_male_pc  afr_amer_pc  amer_ind_pc  asian_pc  \
# GEO_ID
# 0500000US01001     19.902492    48.634886    19.028530     0.252799  1.034670
# 0500000US01003     27.178029    48.628483     9.264671     0.772917  0.925152
# 0500000US01005     25.022673    52.919838    47.576988     0.323331  0.528370
# 0500000US01007     22.442538    54.016805    22.291380     0.133375  0.120037
# 0500000US01009     24.505470    49.401016     1.608849     0.079749  0.367539
# ...                      ...          ...          ...          ...       ...
# 0500000US72145     25.823881    47.829169     4.960530     0.122624  0.017244
# 0500000US72147     28.176348    49.490859     7.532978     0.092571  0.162000
# 0500000US72149     22.764808    48.457796     3.450431     0.000000  0.000000
# 0500000US72151     26.753037    48.365623    78.862056     0.000000  0.032837
# 0500000US72153     27.238343    47.868917     3.799255     0.448798  0.016936
#
#                 latino_pc   white_pc  ...  amer_ind_delta  asian_delta  \
# GEO_ID                                ...
# 0500000US01001   2.825930  76.791260  ...       -0.157744     0.228115
# 0500000US01003   4.562797  86.205422  ...        0.093753     0.254508
# 0500000US01005   4.357084  46.800205  ...        0.150490     0.043663
# 0500000US01007   2.574134  76.788334  ...       -0.225477     0.058014
# 0500000US01009   9.261282  95.459510  ...       -0.268580     0.208104
# ...                   ...        ...  ...             ...          ...
# 0500000US72145  96.740880  83.206239  ...       -0.156615    -0.090156
# 0500000US72147  94.931729  54.732701  ...       -1.156600    -1.783612
# 0500000US72149  99.745570  56.746864  ...       -0.099231    -0.041346
# 0500000US72151  99.919401  18.639362  ...       -0.255116     0.007606
# 0500000US72153  99.364909  75.101615  ...        0.119090     0.001359
#
#                 latino_delta  white_delta     pov_pc  pov_pc_delta  \
# GEO_ID
# 0500000US01001      0.253676    -0.069355  15.059588      2.966775
# 0500000US01003      0.196098    -0.226837  10.197810     -1.807546
# 0500000US01005      0.047322     0.095463  27.108553      2.523560
# 0500000US01007      0.350140    -0.165414  16.627395      1.556040
# 0500000US01009      0.533984     0.018986  13.416896     -2.950712
# ...                      ...          ...        ...           ...
# 0500000US72145      0.186625    -6.626576  44.999234     -3.893317
# 0500000US72147     -1.431305     6.678312  45.672298      8.412405
# 0500000US72149     -0.200680     2.897530  47.498103     -6.891934
# 0500000US72151      0.031540   -35.826575  53.034419      0.486582
# 0500000US72153     -0.282018    -9.020507  48.755222     -5.331941
#
#                 unemp_rate  unemp_delta  mean_hhi  med_hhi
# GEO_ID
# 0500000US01001         3.7         -1.9   75326.0  58731.0
# 0500000US01003         4.3         -2.0   80986.0  58320.0
# 0500000US01005         9.2         -3.6   47068.0  32525.0
# 0500000US01007         7.3          0.2   60182.0  47542.0
# 0500000US01009         3.4         -2.6   65639.0  49358.0
# ...                    ...          ...       ...      ...
# 0500000US72145        17.4          0.1   28805.0  19617.0
# 0500000US72147         7.5         -4.8   22742.0  14936.0
# 0500000US72149        21.9         -2.9   29612.0  19877.0
# 0500000US72151        19.8         -4.4   24078.0  16295.0
# 0500000US72153        20.2         -3.8   21722.0  14743.0
#
# [3220 rows x 21 columns]

# %%
education=pd.read_csv('./education/education_2019_cleaned.csv')
education.set_index('GEO_ID',inplace=True)
education.drop(axis=1,labels=['Unnamed: 0'],inplace=True)

# %%
final_tally['hs_deg']=education['high_school_deg']
final_tally['bac_deg']=education['bachelor_deg']
# Out:
# /tmp/ipykernel_427111/1582709748.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_tally['hs_deg']=education['high_school_deg']
# /tmp/ipykernel_427111/1582709748.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_tally['bac_deg']=education['bachelor_deg']

# %%
r='REPUBLICAN'
d='DEMOCRAT'
election=pd.read_csv('./election_results/countypres_2020.csv')
election=election.loc[(election['year']==2020) & ((election['party']==r)|(election['party']==d))]
election.dropna(inplace=True)

# %%
election['GEO_ID']=election['county_fips'].apply(lambda x:'0500000US'+str(int(x)).zfill(5))

# %%
elections_pc=100*election.groupby(['GEO_ID','party'])['candidatevotes'].sum()/election.groupby(['GEO_ID','party'])['totalvotes'].mean()

# %%
for x in final_tally.index.intersection(election['GEO_ID']):
    final_tally.loc[x,'democrat']=elections_pc[x][d]
    final_tally.loc[x,'republican']=elections_pc[x][r]
# Out:
# /tmp/ipykernel_427111/2620162989.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_tally.loc[x,'democrat']=elections_pc[x][d]
# /tmp/ipykernel_427111/2620162989.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_tally.loc[x,'republican']=elections_pc[x][r]

# %%
final_tally=final_tally.dropna()

# %%
final_tally.to_csv('../aggregate.csv')

# %%
final_tally.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3115 entries, 0500000US01001 to 0500000US56045
# Data columns (total 25 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   NAME            3115 non-null   object
#  1   total_pop       3115 non-null   int64
#  2   pop_18_30_pc    3115 non-null   float64
#  3   pop_60_up_pc    3115 non-null   float64
#  4   pop_male_pc     3115 non-null   float64
#  5   afr_amer_pc     3115 non-null   float64
#  6   amer_ind_pc     3115 non-null   float64
#  7   asian_pc        3115 non-null   float64
#  8   latino_pc       3115 non-null   float64
#  9   white_pc        3115 non-null   float64
#  10  afr_amer_delta  3115 non-null   float64
#  11  amer_ind_delta  3115 non-null   float64
#  12  asian_delta     3115 non-null   float64
#  13  latino_delta    3115 non-null   float64
#  14  white_delta     3115 non-null   float64
#  15  pov_pc          3115 non-null   float64
#  16  pov_pc_delta    3115 non-null   float64
#  17  unemp_rate      3115 non-null   float64
#  18  unemp_delta     3115 non-null   float64
#  19  mean_hhi        3115 non-null   float64
#  20  med_hhi         3115 non-null   float64
#  21  hs_deg          3115 non-null   float64
#  22  bac_deg         3115 non-null   float64
#  23  democrat        3115 non-null   float64
#  24  republican      3115 non-null   float64
# dtypes: float64(23), int64(1), object(1)
# memory usage: 632.7+ KB
